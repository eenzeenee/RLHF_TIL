# %%
import pickle

with open(file='/home/work/data00/dataset/test.pickle', mode='rb') as f:
    test_data=pickle.load(f)

# %%
print(test_data[1])
# Out:
# {'instruction': '뉴베리상과 함께 최고의 아동 문학상으로 인정받고 있는 세계적인 상의 수상자를 발표하는 장소는?', 'input': '뉴베리상. 1922년부터 처음으로 시상되었고 한스 크리스티안 안데르센 상과 더불어 최고의 아동 문학상으로 꼽히고 있다. 상은 최우수 아동용 그림책을 그린 미술가에게 주는 칼데콧 상과 함께 미국도서관협회의 연례총회에서 주고 있다.', 'output': '매년 3월 말이나 4월 초에 열리는 볼로냐아동도서전 현장', 'input_ids': [0, 29871, 30860, 238, 161, 155, 31081, 29871, 239, 161, 148, 239, 154, 136, 31286, 29871, 239, 135, 167, 31976, 30944, 31081, 29871, 31976, 238, 163, 188, 31129, 30906, 29892, 29871, 240, 152, 171, 237, 190, 155, 29871, 239, 161, 136, 238, 163, 168, 238, 147, 155, 31081, 29871, 239, 161, 136, 238, 163, 168, 29871, 31406, 238, 170, 168, 29871, 238, 179, 146, 29871, 238, 142, 184, 238, 182, 131, 31906, 29871, 239, 143, 144, 31286, 29871, 30393, 238, 166, 188, 31063, 30709, 29889, 29871, 30981, 31129, 31536, 29871, 31406, 238, 170, 168, 31054, 29871, 238, 170, 161, 237, 181, 143, 29871, 239, 163, 132, 239, 163, 139, 30877, 29871, 239, 160, 148, 238, 142, 184, 31286, 29871, 239, 161, 148, 31126, 30944, 31578, 31527, 29889
# ...

# %%
all_len = 0
all_cnt = 0
for i in range(len(test_data)):
    all_cnt += 1
    all_len += len(test_data[i]['output'])

print(all_len // all_cnt)
# Out:
# 10

# %%
print(len(test_data))
# Out:
# 9475

# %%
print(all_cnt)
# Out:
# 9475

# %%
test_data[1]['labels']
# Out:
# [0,
#  29871,
#  30860,
#  238,
#  161,
#  155,
#  31081,
#  29871,
#  239,
#  161,
#  148,
#  239,
#  154,
#  136,
#  31286,
#  29871,
#  239,
#  135,
#  167,
#  31976,
#  30944,
#  31081,
#  29871,
#  31976,
#  238,
#  163,
#  188,
#  31129,
#  30906,
#  29892,
#  29871,
#  240,
#  152,
#  171,
#  237,
#  190,
#  155,
#  29871,
#  239,
#  161,
#  136,
#  238,
#  163,
#  168,
#  238,
#  147,
#  155,
#  31081,
#  29871,
#  239,
#  161,
#  136,
#  238,
#  163,
#  168,
#  29871,
#  31406,
#  238,
#  170,
#  168,
#  29871,
#  238,
#  179,
#  146,
#  29871,
#  238,
#  142,
#  184,
#  238,
#  182,
#  131,
#  31906,
#  29871,
#  239,
#  143,
#  144,
#  31286,
#  29871,
#  30393,
#  238,
#  166,
#  188,
#  31063,
#  30709,
#  29889,
#  29871,
#  30981,
#  31129,
#  31536,
#  29871,
#  31406,
#  238,
#  170,
#  168,
#  31054,
#  29871,
#  238,
#  170,
#  161,
#  237,
#  181,
#  143,
#  29871,
#  239,
#  163,
#  132,
#  239,
#  163,
#  139,
#  30877,
#  29871,
#  239,
#  160,
#  148,
#  238,
# ...
